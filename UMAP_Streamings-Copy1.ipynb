# %%
import spotipy.util as util
import spotipy
from numpy import array
from sklearn.preprocessing import LabelEncoder
import umap.umap_ as umap
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
import plotly
import plotly.express as px
from plotly.offline import plot

sns.set(style = 'white',context= 'notebook', rc = {'figure.figsize':(14,10)})

# %%
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import ast
from typing import List
from os import listdir
def get_streamings(path: str = 'Spotify Data') -> List[dict]:
    
    files = ['Spotify Data/' + x for x in listdir(path)
             if x.split('.')[0][:-1] == 'StreamingHistory']
    
    all_streamings = []
    
    for file in files: 
        with open(file, 'r', encoding='UTF-8') as f:
            new_streamings = ast.literal_eval(f.read())
            all_streamings += [streaming for streaming 
                               in new_streamings]
    return all_streamings

# %%
username = '9cjfei8bx9vq78vel4odrjd3y'
client_id ='f2018fb393c2424dba2844c31e8e2c18'
client_secret = 'f4bb9567dafc4625877be647542fd919'
redirect_uri = 'http://localhost:7777/callback'
scope = 'user-read-recently-played user-top-read playlist-read-private user-library-read user-follow-read'

token = util.prompt_for_user_token(username=username, 
scope=scope, 
client_id=client_id,   
client_secret=client_secret,     
redirect_uri=redirect_uri)

# %%
import requests
def get_id(track_name: str, token: str) -> str:
    headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': f'Bearer ' + token,
    }
    params = [
    ('q', track_name),
    ('type', 'track'),
    ]
    try:
        response = requests.get('https://api.spotify.com/v1/search', 
                    headers = headers, params = params, timeout = 5)
        json = response.json()
        first_result = json['tracks']['items'][0]
        track_id = first_result['id']
        return track_id
    except:
        return None

# %%
def get_features(track_id: str, token: str) -> dict:
    sp = spotipy.Spotify(auth=token)
    try:
        features = sp.audio_features([track_id])
        return features[0]
    except:
        return None

# %%
streamings = df = pd.read_pickle('Created_Features\Jazz.pkl')

res = [i for i in streamings if i['msPlayed'] >60000]
df = pd.DataFrame(res)
df
# Out:
#                endTime      artistName  \
# 0     2019-07-02 04:37        Maroon 5
# 1     2019-07-02 04:53        Maroon 5
# 2     2019-07-02 04:58    Fall Out Boy
# 3     2019-07-02 05:02      Fort Minor
# 4     2019-07-02 05:06    Fall Out Boy
# ...                ...             ...
# 4683  2020-07-02 16:18       Van Halen
# 4684  2020-07-02 16:21   Guns N' Roses
# 4685  2020-07-02 16:25  Lynyrd Skynyrd
# 4686  2020-07-02 16:26      Pink Floyd
# 4687  2020-07-02 16:30           AC/DC
#
#                                        trackName  msPlayed
# 0                                 Girls Like You    215229
# 1                                           Wait    190642
# 2                      The Last Of The Real Ones    230400
# 3     Remember the Name (feat. Styles of Beyond)    230493
# 4                                 Fourth Of July    224360
# ...                                          ...       ...
# 4683                    Eruption - 2015 Remaster    102080
# 4684                               November Rain    142689
# 4685                                   Free Bird    234099
# 4686                            Comfortably Numb     94231
# 4687                 You Shook Me All Night Long    210880
#
# [4688 rows x 4 columns]

# %%
df = df.sort_values(by=['msPlayed'],ascending = False)
df = df.drop_duplicates("trackName", keep = 'first')
df = df.reset_index(drop = True)
df
# Out:
#               endTime       artistName  \
# 0    2019-12-02 14:54  Kumar Gandharva
# 1    2019-12-31 21:47      Miles Davis
# 2    2020-05-04 05:45       The Weeknd
# 3    2019-10-01 04:17   Lynyrd Skynyrd
# 4    2019-12-31 22:05      Miles Davis
# ..                ...              ...
# 927  2019-11-09 18:19   Franz Schubert
# 928  2020-03-02 13:40      Sleepermane
# 929  2020-03-11 15:22          Rajstar
# 930  2019-09-29 17:57  Lata Mangeshkar
# 931  2020-06-22 15:57        Green Day
#
#                                              trackName  msPlayed
# 0                                     Runanubandhachya    737531
# 1                                            All Blues    692745
# 2                                         In Your Eyes    621062
# 3                                            Free Bird    614118
# 4                                              So What    562620
# ..                                                 ...       ...
# 927  Schwanengesang, D. 957: 4. Ständchen In D Mino...     61606
# 928                                             Frosty     61533
# 929                                                Shh     60778
# 930        Tum Aa Gaye Ho Noor Aa Gaya (From "Aandhi")     60595
# 931                  Good Riddance (Time of Your Life)     60272
#
# [932 rows x 4 columns]

# %%
df1= df['endTime'].str.split("-",n=1,expand = True)
df['endTime'] = df1[0]
df = df[df['endTime']=='2020']

# %%
df = df.reset_index(drop = True)

# %%
unique_tracks = list(set(df['trackName']))
len(unique_tracks)
# Out:
# 403

# %%
#Get All features for the top tracks
all_features = {}
for track in unique_tracks:
    track_id = get_id(track, token)
    features = get_features(track_id, token)
    if features:
        all_features[track] = features

# %%
all1 = pd.DataFrame(all_features)
all2 = all1.transpose()
all2 = all2.reset_index()
all2 = all2.rename(columns={'index':'trackName'})
all2
# Out:
#                                              trackName danceability energy  \
# 0                                             Umbrella        0.583  0.829
# 1                                     Thnks fr th Mmrs        0.459  0.891
# 2                                           Victorious         0.57  0.865
# 3                                             Minority        0.551  0.965
# 4                                    Until I Bleed Out        0.245  0.394
# ..                                                 ...          ...    ...
# 393                                    Black And White        0.443  0.582
# 394                                  You're All I Want        0.439  0.469
# 395                                Gold on the Ceiling        0.505  0.833
# 396  Lying Is the Most Fun a Girl Can Have Without ...         0.66  0.799
# 397                                      Drugs & Candy         0.49  0.868
#
#     key loudness mode speechiness acousticness instrumentalness liveness  \
# 0     1   -4.603    1       0.134      0.00864                0   0.0426
# 1    10   -5.057    0      0.0623      0.00511                0    0.106
# 2     8   -4.518    1      0.0472      0.00205                0    0.404
# 3     0   -2.772    1      0.0452      0.00576                0    0.171
# 4     0   -9.887    0      0.0374        0.423          2.9e-05    0.093
# ..   ..      ...  ...         ...          ...              ...      ...
# 393   2    -6.02    1      0.0482       0.0301                0    0.127
# 394   5  -10.949    1      0.0244        0.365            0.812    0.113
# 395   0   -4.632    1      0.0475      0.00772          7.9e-05    0.069
# 396   8   -4.644    1      0.0995        0.106                0    0.154
# 397  10   -3.943    1      0.0375       0.0486                0   0.0575
#
#     valence    tempo            type                      id  \
# 0     0.575  174.028  audio_features  49FYlytm3dAAraYgpoJZux
# 1     0.588  154.837  audio_features  3Zwu2K0Qa5sT6teCCHPShP
# 2     0.691   110.01  audio_features  6od5hFv9IT5JHc7NEF9HRv
# 3     0.708  137.841  audio_features  4qjfQnccStTR8zNsb6Mizo
# 4     0.148  115.233  audio_features  2BcnxwxBuar5wjCaLqm5N3
# ..      ...      ...             ...                     ...
# 393   0.239  147.589  audio_features  7rpNuuoMbid56XkDsx2FjE
# 394   0.276   90.985  audio_features  4nvLuqwTOZdEJI1fcHXv8h
# 395   0.565  130.121  audio_features  5lN1EH25gdiqT1SFALMAq1
# 396   0.475  125.966  audio_features  7wOmQJeVX6qjNXqqsKOkPx
# 397   0.472  147.979  audio_features  1isQMKYmpvJ4tOP8R2qkWr
#
#                                       uri  \
# 0    spotify:track:49FYlytm3dAAraYgpoJZux
# 1    spotify:track:3Zwu2K0Qa5sT6teCCHPShP
# 2    spotify:track:6od5hFv9IT5JHc7NEF9HRv
# 3    spotify:track:4qjfQnccStTR8zNsb6Mizo
# 4    spotify:track:2BcnxwxBuar5wjCaLqm5N3
# ..                                    ...
# 393  spotify:track:7rpNuuoMbid56XkDsx2FjE
# 394  spotify:track:4nvLuqwTOZdEJI1fcHXv8h
# 395  spotify:track:5lN1EH25gdiqT1SFALMAq1
# 396  spotify:track:7wOmQJeVX6qjNXqqsKOkPx
# 397  spotify:track:1isQMKYmpvJ4tOP8R2qkWr
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/49FYlytm3dAA...
# 1    https://api.spotify.com/v1/tracks/3Zwu2K0Qa5sT...
# 2    https://api.spotify.com/v1/tracks/6od5hFv9IT5J...
# 3    https://api.spotify.com/v1/tracks/4qjfQnccStTR...
# 4    https://api.spotify.com/v1/tracks/2BcnxwxBuar5...
# ..                                                 ...
# 393  https://api.spotify.com/v1/tracks/7rpNuuoMbid5...
# 394  https://api.spotify.com/v1/tracks/4nvLuqwTOZdE...
# 395  https://api.spotify.com/v1/tracks/5lN1EH25gdiq...
# 396  https://api.spotify.com/v1/tracks/7wOmQJeVX6qj...
# 397  https://api.spotify.com/v1/tracks/1isQMKYmpvJ4...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/49FY...      275987
# 1    https://api.spotify.com/v1/audio-analysis/3Zwu...      203507
# 2    https://api.spotify.com/v1/audio-analysis/6od5...      178600
# 3    https://api.spotify.com/v1/audio-analysis/4qjf...      168227
# 4    https://api.spotify.com/v1/audio-analysis/2Bcn...      190173
# ..                                                 ...         ...
# 393  https://api.spotify.com/v1/audio-analysis/7rpN...      193090
# 394  https://api.spotify.com/v1/audio-analysis/4nvL...      264453
# 395  https://api.spotify.com/v1/audio-analysis/5lN1...      224333
# 396  https://api.spotify.com/v1/audio-analysis/7wOm...      200227
# 397  https://api.spotify.com/v1/audio-analysis/1isQ...      217680
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                3
# ..             ...
# 393              4
# 394              4
# 395              4
# 396              4
# 397              4
#
# [398 rows x 19 columns]

# %%
merged = pd.merge(all2,df,how ='inner',left_on = 'trackName', right_on ='trackName')
merged
# Out:
#                                              trackName danceability energy  \
# 0                                             Umbrella        0.583  0.829
# 1                                     Thnks fr th Mmrs        0.459  0.891
# 2                                           Victorious         0.57  0.865
# 3                                             Minority        0.551  0.965
# 4                                    Until I Bleed Out        0.245  0.394
# ..                                                 ...          ...    ...
# 393                                    Black And White        0.443  0.582
# 394                                  You're All I Want        0.439  0.469
# 395                                Gold on the Ceiling        0.505  0.833
# 396  Lying Is the Most Fun a Girl Can Have Without ...         0.66  0.799
# 397                                      Drugs & Candy         0.49  0.868
#
#     key loudness mode speechiness acousticness instrumentalness liveness  ...  \
# 0     1   -4.603    1       0.134      0.00864                0   0.0426  ...
# 1    10   -5.057    0      0.0623      0.00511                0    0.106  ...
# 2     8   -4.518    1      0.0472      0.00205                0    0.404  ...
# 3     0   -2.772    1      0.0452      0.00576                0    0.171  ...
# 4     0   -9.887    0      0.0374        0.423          2.9e-05    0.093  ...
# ..   ..      ...  ...         ...          ...              ...      ...  ...
# 393   2    -6.02    1      0.0482       0.0301                0    0.127  ...
# 394   5  -10.949    1      0.0244        0.365            0.812    0.113  ...
# 395   0   -4.632    1      0.0475      0.00772          7.9e-05    0.069  ...
# 396   8   -4.644    1      0.0995        0.106                0    0.154  ...
# 397  10   -3.943    1      0.0375       0.0486                0   0.0575  ...
#
#                type                      id  \
# 0    audio_features  49FYlytm3dAAraYgpoJZux
# 1    audio_features  3Zwu2K0Qa5sT6teCCHPShP
# 2    audio_features  6od5hFv9IT5JHc7NEF9HRv
# 3    audio_features  4qjfQnccStTR8zNsb6Mizo
# 4    audio_features  2BcnxwxBuar5wjCaLqm5N3
# ..              ...                     ...
# 393  audio_features  7rpNuuoMbid56XkDsx2FjE
# 394  audio_features  4nvLuqwTOZdEJI1fcHXv8h
# 395  audio_features  5lN1EH25gdiqT1SFALMAq1
# 396  audio_features  7wOmQJeVX6qjNXqqsKOkPx
# 397  audio_features  1isQMKYmpvJ4tOP8R2qkWr
#
#                                       uri  \
# 0    spotify:track:49FYlytm3dAAraYgpoJZux
# 1    spotify:track:3Zwu2K0Qa5sT6teCCHPShP
# 2    spotify:track:6od5hFv9IT5JHc7NEF9HRv
# 3    spotify:track:4qjfQnccStTR8zNsb6Mizo
# 4    spotify:track:2BcnxwxBuar5wjCaLqm5N3
# ..                                    ...
# 393  spotify:track:7rpNuuoMbid56XkDsx2FjE
# 394  spotify:track:4nvLuqwTOZdEJI1fcHXv8h
# 395  spotify:track:5lN1EH25gdiqT1SFALMAq1
# 396  spotify:track:7wOmQJeVX6qjNXqqsKOkPx
# 397  spotify:track:1isQMKYmpvJ4tOP8R2qkWr
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/49FYlytm3dAA...
# 1    https://api.spotify.com/v1/tracks/3Zwu2K0Qa5sT...
# 2    https://api.spotify.com/v1/tracks/6od5hFv9IT5J...
# 3    https://api.spotify.com/v1/tracks/4qjfQnccStTR...
# 4    https://api.spotify.com/v1/tracks/2BcnxwxBuar5...
# ..                                                 ...
# 393  https://api.spotify.com/v1/tracks/7rpNuuoMbid5...
# 394  https://api.spotify.com/v1/tracks/4nvLuqwTOZdE...
# 395  https://api.spotify.com/v1/tracks/5lN1EH25gdiq...
# 396  https://api.spotify.com/v1/tracks/7wOmQJeVX6qj...
# 397  https://api.spotify.com/v1/tracks/1isQMKYmpvJ4...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/49FY...      275987
# 1    https://api.spotify.com/v1/audio-analysis/3Zwu...      203507
# 2    https://api.spotify.com/v1/audio-analysis/6od5...      178600
# 3    https://api.spotify.com/v1/audio-analysis/4qjf...      168227
# 4    https://api.spotify.com/v1/audio-analysis/2Bcn...      190173
# ..                                                 ...         ...
# 393  https://api.spotify.com/v1/audio-analysis/7rpN...      193090
# 394  https://api.spotify.com/v1/audio-analysis/4nvL...      264453
# 395  https://api.spotify.com/v1/audio-analysis/5lN1...      224333
# 396  https://api.spotify.com/v1/audio-analysis/7wOm...      200227
# 397  https://api.spotify.com/v1/audio-analysis/1isQ...      217680
#
#     time_signature endTime            artistName msPlayed
# 0                4    2020               Rihanna   507016
# 1                4    2020          Fall Out Boy   203506
# 2                4    2020   Panic! At The Disco   178600
# 3                4    2020             Green Day   162822
# 4                3    2020            The Weeknd   179357
# ..             ...     ...                   ...      ...
# 393              4    2020           Niall Horan   193089
# 394              4    2020  Cigarettes After Sex   154586
# 395              4    2020        The Black Keys   102881
# 396              4    2020   Panic! At The Disco    88503
# 397              4    2020          All Time Low   126720
#
# [398 rows x 22 columns]

# %%
le1 = LabelEncoder()
ie1= le1.fit_transform(array(merged['artistName']))
merged['code']= pd.DataFrame(ie1)
merged['code'] = merged['code'].astype('int')
merged['code'].unique()
# Out:
# array([154,  61, 143,  70, 187, 186,  43,  37, 133,  62,  85,  88, 217,
#         98, 109,  53, 214, 177, 163,  47, 166,  77, 222, 110, 175, 127,
#        149,  44,  83, 151, 122, 116,  71, 126, 119,  92, 179, 117,  22,
#          8,  81,  24, 132,  64,  65,  96,  87, 189, 100,  15,  46, 105,
#        111,  16,   2, 142, 125,  59, 181,  78, 191,  39,  45, 164, 204,
#        195, 190, 162,  90, 124,   9, 221,  57, 205,   4,  55,  31,   3,
#        136, 147,  80,  36, 152, 193, 157, 128, 172,  27, 135, 210, 153,
#        115, 178, 161, 192, 180,  49, 112, 138, 199,  25, 174, 209,   7,
#        148,  75, 146,  91, 165, 167, 169,  28, 218, 145,  93, 134,  79,
#         38, 103,  40,  82,  56, 171, 196,  12,  94, 129, 202, 213,  58,
#         60, 206, 131,  23,  17, 200,  21,  33,  32,  14, 101,  76, 107,
#         34, 170,   1, 141,  67, 223, 155,  84, 144, 197,  10,  54,   5,
#        212, 201,  52,  35,  11,  42,  30, 137, 188,  72,  13, 173,  26,
#        198, 120, 130,  20, 118, 215,  48, 106, 139, 168,  51, 140,  29,
#        194, 150,  41, 211,  69, 160, 158, 203, 104,  18, 182,  99,  95,
#        219, 121, 184, 108,  86, 156,  66,  97, 216, 123, 185, 113,  89,
#        220,  63, 208, 114, 207, 102, 183,  74,   0,  50,  19, 159,  73,
#         68, 176,   6])

# %%
display(merged.iloc[3,:])
# Out:
# trackName                                                    Minority
# danceability                                                    0.551
# energy                                                          0.965
# key                                                                 0
# loudness                                                       -2.772
# mode                                                                1
# speechiness                                                    0.0452
# acousticness                                                  0.00576
# instrumentalness                                                    0
# liveness                                                        0.171
# valence                                                         0.708
# tempo                                                         137.841
# type                                                   audio_features
# id                                             4qjfQnccStTR8zNsb6Mizo
# uri                              spotify:track:4qjfQnccStTR8zNsb6Mizo
# track_href          https://api.spotify.com/v1/tracks/4qjfQnccStTR...
# analysis_url        https://api.spotify.com/v1/audio-analysis/4qjf...
# duration_ms                                                    168227
# time_signature                                                      4
# endTime                                                          2020
# artistName                                                  Green Day
# msPlayed                                                       162822
# code                                                               70
# Name: 3, dtype: object

# %%
reducer = umap.UMAP(n_neighbors = 20)

prescale = merged.iloc[:,1:12].values #select only dimensional data
scaled= StandardScaler().fit_transform(prescale)
scaled.shape
# Out:
# (398, 11)

# %%
embedding = reducer.fit_transform(scaled)

# %%
embed_df = pd.DataFrame(embedding)
merged['X']=0
merged['Y']=0
merged.iloc[:,23] = embed_df.iloc[:,0]
merged.iloc[:,24] = embed_df.iloc[:,1]
merged
# Out:
#                                              trackName danceability energy  \
# 0                                             Umbrella        0.583  0.829
# 1                                     Thnks fr th Mmrs        0.459  0.891
# 2                                           Victorious         0.57  0.865
# 3                                             Minority        0.551  0.965
# 4                                    Until I Bleed Out        0.245  0.394
# ..                                                 ...          ...    ...
# 393                                    Black And White        0.443  0.582
# 394                                  You're All I Want        0.439  0.469
# 395                                Gold on the Ceiling        0.505  0.833
# 396  Lying Is the Most Fun a Girl Can Have Without ...         0.66  0.799
# 397                                      Drugs & Candy         0.49  0.868
#
#     key loudness mode speechiness acousticness instrumentalness liveness  ...  \
# 0     1   -4.603    1       0.134      0.00864                0   0.0426  ...
# 1    10   -5.057    0      0.0623      0.00511                0    0.106  ...
# 2     8   -4.518    1      0.0472      0.00205                0    0.404  ...
# 3     0   -2.772    1      0.0452      0.00576                0    0.171  ...
# 4     0   -9.887    0      0.0374        0.423          2.9e-05    0.093  ...
# ..   ..      ...  ...         ...          ...              ...      ...  ...
# 393   2    -6.02    1      0.0482       0.0301                0    0.127  ...
# 394   5  -10.949    1      0.0244        0.365            0.812    0.113  ...
# 395   0   -4.632    1      0.0475      0.00772          7.9e-05    0.069  ...
# 396   8   -4.644    1      0.0995        0.106                0    0.154  ...
# 397  10   -3.943    1      0.0375       0.0486                0   0.0575  ...
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/49FYlytm3dAA...
# 1    https://api.spotify.com/v1/tracks/3Zwu2K0Qa5sT...
# 2    https://api.spotify.com/v1/tracks/6od5hFv9IT5J...
# 3    https://api.spotify.com/v1/tracks/4qjfQnccStTR...
# 4    https://api.spotify.com/v1/tracks/2BcnxwxBuar5...
# ..                                                 ...
# 393  https://api.spotify.com/v1/tracks/7rpNuuoMbid5...
# 394  https://api.spotify.com/v1/tracks/4nvLuqwTOZdE...
# 395  https://api.spotify.com/v1/tracks/5lN1EH25gdiq...
# 396  https://api.spotify.com/v1/tracks/7wOmQJeVX6qj...
# 397  https://api.spotify.com/v1/tracks/1isQMKYmpvJ4...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/49FY...      275987
# 1    https://api.spotify.com/v1/audio-analysis/3Zwu...      203507
# 2    https://api.spotify.com/v1/audio-analysis/6od5...      178600
# 3    https://api.spotify.com/v1/audio-analysis/4qjf...      168227
# 4    https://api.spotify.com/v1/audio-analysis/2Bcn...      190173
# ..                                                 ...         ...
# 393  https://api.spotify.com/v1/audio-analysis/7rpN...      193090
# 394  https://api.spotify.com/v1/audio-analysis/4nvL...      264453
# 395  https://api.spotify.com/v1/audio-analysis/5lN1...      224333
# 396  https://api.spotify.com/v1/audio-analysis/7wOm...      200227
# 397  https://api.spotify.com/v1/audio-analysis/1isQ...      217680
#
#     time_signature endTime            artistName msPlayed code          X  \
# 0                4    2020               Rihanna   507016  154   9.022719
# 1                4    2020          Fall Out Boy   203506   61   3.525424
# 2                4    2020   Panic! At The Disco   178600  143  11.307363
# 3                4    2020             Green Day   162822   70  10.473837
# 4                3    2020            The Weeknd   179357  187   4.569621
# ..             ...     ...                   ...      ...  ...        ...
# 393              4    2020           Niall Horan   193089  135   8.954543
# 394              4    2020  Cigarettes After Sex   154586   37   6.858513
# 395              4    2020        The Black Keys   102881  176   9.970233
# 396              4    2020   Panic! At The Disco    88503  143  10.119087
# 397              4    2020          All Time Low   126720    6  10.543971
#
#             Y
# 0    6.648100
# 1    5.051473
# 2    3.784301
# 3    5.363281
# 4    5.273177
# ..        ...
# 393  6.122275
# 394  3.091592
# 395  5.514824
# 396  3.471600
# 397  6.365454
#
# [398 rows x 25 columns]

# %%
fig = px.scatter(merged, x= 'X', y = "Y", color = 'artistName', hover_data=['trackName','artistName'])
plot(fig)
# Out:
# 'temp-plot.html'

# %%
plt.scatter(
    merged.iloc[:, 23],
    merged.iloc[:, 24],
    c=merged['code'],
    cmap='viridis')
plt.show()

# %%
sphere_mapper = umap.UMAP(output_metric='haversine', random_state=42).fit(scaled)

# %%
x = np.sin(sphere_mapper.embedding_[:, 0]) * np.cos(sphere_mapper.embedding_[:, 1])
y = np.sin(sphere_mapper.embedding_[:, 0]) * np.sin(sphere_mapper.embedding_[:, 1])
z = np.cos(sphere_mapper.embedding_[:, 0])

# %%
sph = merged 
sph['Z']=0
sph.iloc[:,23] = x
sph.iloc[:,24] = y
sph.iloc[:,25] = z

# %%
fig = px.scatter_3d(sph, x= 'X', y = "Y",z ='Z', color = 'artistName', hover_data=['trackName','artistName'])
plot(fig)
# Out:
# 'temp-plot.html'
