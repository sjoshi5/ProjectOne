# %%
from  helpers import *
from data_gen import *
import spotipy
from spotipy import SpotifyClientCredentials, util
from IPython.core.display import clear_output

import pandas as pd 
import pandasql as ps 
import time
import sqlite3

# %%
df= get_data('7fQZgMLfn5IOyxB0olepjP',15)
# Out:
# Music Downloaded!

# %%
df
# Out:
#                                name  \
# 0                           Georgia
# 1                           Riptide
# 2                  Do I Wanna Know?
# 3                         R U Mine?
# 4            Fluorescent Adolescent
# 5                    Snap Out Of It
# 6                  Four Out Of Five
# 7            When The Sun Goes Down
# 8                          Arabella
# 9                         Free Bird
# 10       The Less I Know The Better
# 11                Take Me To Church
# 12                          Ophelia
# 13  Here Comes The Sun - Remastered
# 14                       Wonderwall
#
#                                             album          artist  \
# 0                            Dream Your Life Away       Vance Joy
# 1                            Dream Your Life Away       Vance Joy
# 2                                              AM  Arctic Monkeys
# 3                                              AM  Arctic Monkeys
# ...
