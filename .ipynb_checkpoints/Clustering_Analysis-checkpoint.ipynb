# %%
import spotipy.util as util
import spotipy
import pandas as pd
import numpy as np
import json
import time
import sys
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
import plotly.graph_objects as go
from collections import OrderedDict
from math import log
import calmap
sp = spotipy.Spotify(auth=token)

# %%
import plotly
from plotly.offline import download_plotlyjs, init_notebook_mode,plot,iplot

#plotly setup
init_notebook_mode(connected=True)

pd.set_option('display.max_colwidth', None)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Generate token - If generated it uses the existing
username = '9cjfei8bx9vq78vel4odrjd3y'
client_id ='f2018fb393c2424dba2844c31e8e2c18'
client_secret = 'f4bb9567dafc4625877be647542fd919'
redirect_uri = 'http://localhost:7777/callback'
scope = 'user-read-recently-played user-top-read playlist-read-private user-library-read user-follow-read'

token = util.prompt_for_user_token(username=username, 
scope=scope, 
client_id=client_id,   
client_secret=client_secret,     
redirect_uri=redirect_uri)

# %%
#Get ID for song
import requests
def get_id(track_name: str,artist_name: str, token: str) -> str:
    headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': f'Bearer ' + token,
    }
    params = [
    ('q', track_name + ' ' + artist_name),
    ('type', 'track'),
    ]
    try:
        response = requests.get('https://api.spotify.com/v1/search', 
                    headers = headers, params = params, timeout = 5)
        json = response.json()
        #print(json)
        first_result = json['tracks']['items'][0]
        print(first_result)
        track_id = first_result['id']
        return track_id
    except:
        return None

# %%
id0 = get_id('Blinding Lights', 'The Weeknd', token)

# %%
# Get features using track-id
def get_features(track_id: str, token: str) -> dict:
    sp = spotipy.Spotify(auth=token)
    try:
        features = sp.audio_features([track_id])
        print(features)
        return features[0]
    except:
        return None

# %%
id0 = get_id('Blinding Lights', 'The Weeknd', token)
feat = get_features(id0,token)
feat

# %%
top = pd.read_pickle('top_features.pkl')

# %%
top
# Out:
#                             trackName danceability energy key loudness mode  \
# 0                      One More Night        0.716  0.821   5   -3.435    0
# 1                          In The End        0.556  0.864   3    -5.87    0
# 2                         Basket Case        0.442  0.943   3   -3.205    1
# 3   Give Me Novacaine / She's a Rebel        0.312  0.949   9   -3.533    1
# 4            I Knew You Were Trouble.        0.622  0.469   3   -6.798    0
# ..                                ...          ...    ...  ..      ...  ...
# 67                          Free Bird        0.168  0.894   0   -4.267    1
# 68                             Ritual        0.647  0.726   3   -4.389    0
# 69                       Seeing Blind        0.716  0.555   9    -7.57    1
# 70                   Story of My Life          0.6  0.663   3   -5.802    1
# 71                        Black Magic        0.777  0.895   4   -4.464    1
#
#    speechiness acousticness instrumentalness liveness valence    tempo  \
# 0       0.0314       0.0558                0   0.0844   0.618   92.997
# 1       0.0584      0.00958                0    0.209     0.4  105.143
# 2       0.0602      0.00293         8.71e-06    0.091   0.781   85.064
# 3       0.0784      0.00185         1.78e-05   0.0569    0.65  154.795
# 4       0.0363      0.00454         2.25e-06   0.0335   0.679   77.019
# ..         ...          ...              ...      ...     ...      ...
# 67      0.0601       0.0015          0.00896   0.0642   0.378  151.855
# 68      0.0552        0.157                0   0.0844   0.767  114.996
# 69      0.0368       0.0395                0    0.105   0.485   93.974
# 70      0.0477        0.225                0    0.119   0.286   121.07
# 71      0.0618       0.0348                0    0.317   0.826  111.987
#
#               type                      id  \
# 0   audio_features  6cpk00i5TxCqSeqNi2HuIe
# 1   audio_features  60a0Rd6pjrkxjPbaKzXjfq
# 2   audio_features  6L89mwZXSOwYl76YXfX13s
# 3   audio_features  11I3KKHv7g2pXiuqRDabRA
# 4   audio_features  6FB3v4YcR57y4tXFcdxI1E
# ..             ...                     ...
# 67  audio_features  6CosyyANTKr1WY6aEeENSw
# 68  audio_features  3M9Apu4OZfylLTFKvgEtKa
# 69  audio_features  65wnZsZLKJimfK1cTFOfa1
# 70  audio_features  4nVBt6MZDDP6tRVdQTgxJg
# 71  audio_features  5y6pj7OeBFF0CVgZKhRbOG
#
#                                      uri  \
# 0   spotify:track:6cpk00i5TxCqSeqNi2HuIe
# 1   spotify:track:60a0Rd6pjrkxjPbaKzXjfq
# 2   spotify:track:6L89mwZXSOwYl76YXfX13s
# 3   spotify:track:11I3KKHv7g2pXiuqRDabRA
# 4   spotify:track:6FB3v4YcR57y4tXFcdxI1E
# ..                                   ...
# 67  spotify:track:6CosyyANTKr1WY6aEeENSw
# 68  spotify:track:3M9Apu4OZfylLTFKvgEtKa
# 69  spotify:track:65wnZsZLKJimfK1cTFOfa1
# 70  spotify:track:4nVBt6MZDDP6tRVdQTgxJg
# 71  spotify:track:5y6pj7OeBFF0CVgZKhRbOG
#
#                                                   track_href  \
# 0   https://api.spotify.com/v1/tracks/6cpk00i5TxCqSeqNi2HuIe
# 1   https://api.spotify.com/v1/tracks/60a0Rd6pjrkxjPbaKzXjfq
# 2   https://api.spotify.com/v1/tracks/6L89mwZXSOwYl76YXfX13s
# 3   https://api.spotify.com/v1/tracks/11I3KKHv7g2pXiuqRDabRA
# 4   https://api.spotify.com/v1/tracks/6FB3v4YcR57y4tXFcdxI1E
# ..                                                       ...
# 67  https://api.spotify.com/v1/tracks/6CosyyANTKr1WY6aEeENSw
# 68  https://api.spotify.com/v1/tracks/3M9Apu4OZfylLTFKvgEtKa
# 69  https://api.spotify.com/v1/tracks/65wnZsZLKJimfK1cTFOfa1
# 70  https://api.spotify.com/v1/tracks/4nVBt6MZDDP6tRVdQTgxJg
# 71  https://api.spotify.com/v1/tracks/5y6pj7OeBFF0CVgZKhRbOG
#
#          analysis_url duration_ms time_signature
# 0            Maroon 5      219547              4
# 1   Black Veil Brides      216880              4
# 2           Green Day      181533              4
# 3           Green Day      326200              4
# 4        Taylor Swift      219720              4
# ..                ...         ...            ...
# 67     Lynyrd Skynyrd      547600              4
# 68  Black Veil Brides      198996              4
# 69        Niall Horan      185281              4
# 70      One Direction      245493              4
# 71         Little Mix      211773              4
#
# [72 rows x 19 columns]

# %%
#Get Artist ID for song
import requests
def get_artist_id(track_name: str,artist_name: str, token: str) -> str:
    headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': f'Bearer ' + token,
    }
    params = [
    ('q', track_name + ' ' + artist_name),
    ('type', 'track'),
    ]
    try:
        response = requests.get('https://api.spotify.com/v1/search', 
                    headers = headers, params = params, timeout = 5)
        json = response.json()
        #print(json)
        first_result = json['tracks']['items'][0]
        #print(first_result)
        id0 = first_result['artists']
        id1 = id0[0] 
        artist_id = id1['id']
        return artist_id
    except:
        return None

# %%
artist_list = pd.DataFrame(top.iloc[:,16])
artist_list['id'] = 'id'
artist_list['track'] = top.iloc[:,0]
artist_list
# Out:
#          analysis_url  id                              track
# 0            Maroon 5  id                     One More Night
# 1   Black Veil Brides  id                         In The End
# 2           Green Day  id                        Basket Case
# 3           Green Day  id  Give Me Novacaine / She's a Rebel
# 4        Taylor Swift  id           I Knew You Were Trouble.
# ..                ...  ..                                ...
# 67     Lynyrd Skynyrd  id                          Free Bird
# 68  Black Veil Brides  id                             Ritual
# 69        Niall Horan  id                       Seeing Blind
# 70      One Direction  id                   Story of My Life
# 71         Little Mix  id                        Black Magic
#
# [72 rows x 3 columns]

# %%
artist_list['id'] = 'id'
row,col = artist_list.shape 
for i in range(0,row):
    artist_list.iloc[i,1] = get_artist_id(artist_list.iloc[i,2],artist_list.iloc[i,0],token)
artist_list
# Out:
#          analysis_url                      id  \
# 0            Maroon 5  04gDigrS5kc9YWfZHwBETP
# 1   Black Veil Brides  6O7MpKrY91vlCd4Osi6XKs
# 2           Green Day  7oPftvlwr6VrsViSDV7fJY
# 3           Green Day  7oPftvlwr6VrsViSDV7fJY
# 4        Taylor Swift  06HL4z0CvFAxyc27GXpf02
# ..                ...                     ...
# 67     Lynyrd Skynyrd  4MVyzYMgTwdP7Z49wAZHx0
# 68  Black Veil Brides  6O7MpKrY91vlCd4Osi6XKs
# 69        Niall Horan  1Hsdzj7Dlq2I7tHP7501T4
# 70      One Direction  4AK6F7OLvEQ5QYCBNiQWHq
# 71         Little Mix  3e7awlrlDSwF3iM0WBjGMp
#
#                                 track
# 0                      One More Night
# 1                          In The End
# 2                         Basket Case
# 3   Give Me Novacaine / She's a Rebel
# 4            I Knew You Were Trouble.
# ..                                ...
# 67                          Free Bird
# 68                             Ritual
# 69                       Seeing Blind
# 70                   Story of My Life
# 71                        Black Magic
#
# [72 rows x 3 columns]

# %%
artist_list = artist_list.drop_duplicates(subset='id')
artist_list = artist_list.reset_index(drop ='True')
artist_list
# Out:
#                 analysis_url                      id  \
# 0                   Maroon 5  04gDigrS5kc9YWfZHwBETP
# 1          Black Veil Brides  6O7MpKrY91vlCd4Osi6XKs
# 2                  Green Day  7oPftvlwr6VrsViSDV7fJY
# 3               Taylor Swift  06HL4z0CvFAxyc27GXpf02
# 4            Chris Stapleton  4YLtscXsxbVgi031ovDDdh
# 5             Arctic Monkeys  7Ln80lUS6He07XvHI8qqHH
# 6                 The Weeknd  1Xyo4u8uXC1ZmMpatF05PJ
# 7                 Little Mix  3e7awlrlDSwF3iM0WBjGMp
# 8                         U2  51Blml2LZPmy7TTiAg47vQ
# 9                   Don Omar  33ScadVnbm2X8kkUqOkC6Z
# 10           The Local Train  7b6Ui7JVaBDEfZB9k6nHL0
# 11               Cheat Codes  7DMveApC7UnC2NPfPvlHSU
# 12                 Vance Joy  10exVja0key0uqUkk6LJRT
# 13               OneRepublic  5Pwc4xIPtQLFEnJriah9YJ
# 14              Daddy Yankee  4VMYDCV2IEDYJArk749S6m
# 15              Shawn Mendes  7n2wHs1TKAczGzO7Dd2rGr
# 16              Fall Out Boy  4UXqAaa6dQYAk18Lv7PEgX
# 17             The Lumineers  16oZKvXb6WkQlVAjwo2Wbg
# 18                     AC/DC  711MCceyCBcFnzjGY4Q7Un
# 19                Ed Sheeran  6eUKZXaKkcviH0Ku9w2n3V
# 20                     Oasis  2DaxqgrOhkeH0fpeiQq2f4
# 21              Charlie Puth  6VuMaDnrHyPL1p4EHjYLi7
# 22       Panic! At The Disco  20JZFwl6HVl6yg8a4H3ZqK
# 23            Lynyrd Skynyrd  4MVyzYMgTwdP7Z49wAZHx0
# 24  Anand Bhaskar Collective  45m11y8OUyx5EgHiKvEC3c
# 25               George Ezra  2ysnwxxNtSgbb9t1m2Ur4j
# 26                      CNCO  0eecdvMrqBftK0M1VKhaF4
# 27            Jonas Brothers  7gOdHgIoIKoe4i9Tta6qdD
# 28                  Sam Hunt  2kucQ9jQwuD8jWdtR9Ef38
# 29                    Hozier  2FXC3k01G6Gw61bmprjgqS
# 30              Arijit Singh  4YRxDV8wJFPHPTeXepOstw
# 31                      DNCE  6T5tfhQCknKG4UnH90qGnz
# 32              All Time Low  46gyXjRIvN1NL1eCB8GBxo
# 33               Niall Horan  1Hsdzj7Dlq2I7tHP7501T4
# 34             One Direction  4AK6F7OLvEQ5QYCBNiQWHq
#
#                               track
# 0                    One More Night
# 1                        In The End
# 2                       Basket Case
# 3          I Knew You Were Trouble.
# 4                 Tennessee Whiskey
# 5                         R U Mine?
# 6                   Save Your Tears
# 7                             Touch
# 8                     Beautiful Day
# 9                      Danza Kuduro
# 10                         Dil Mere
# 11       Only You (with Little Mix)
# 12                          Riptide
# 13                          Secrets
# 14                             Dura
# 15                         Señorita
# 16                   Fourth Of July
# 17                          Ophelia
# 18                  Highway to Hell
# 19  Beautiful People (feat. Khalid)
# 20          Wonderwall - Remastered
# 21                        Attention
# 22       I Write Sins Not Tragedies
# 23               Sweet Home Alabama
# 24                           Malhar
# 25                         Budapest
# 26          Reggaetón Lento (Remix)
# 27              What A Man Gotta Do
# 28            Body Like A Back Road
# 29                Take Me To Church
# 30            Ghungroo (From "War")
# 31                       Truthfully
# 32              Last Young Renegade
# 33                     Seeing Blind
# 34                 Story of My Life

# %%
# Out:
#     level_0  index              analysis_url                      id  \
# 0         0      0                  Maroon 5  04gDigrS5kc9YWfZHwBETP
# 1         1      1         Black Veil Brides  6O7MpKrY91vlCd4Osi6XKs
# 2         2      2                 Green Day  7oPftvlwr6VrsViSDV7fJY
# 3         3      4              Taylor Swift  06HL4z0CvFAxyc27GXpf02
# 4         4      5           Chris Stapleton  4YLtscXsxbVgi031ovDDdh
# 5         5      8            Arctic Monkeys  7Ln80lUS6He07XvHI8qqHH
# 6         6      9                The Weeknd  1Xyo4u8uXC1ZmMpatF05PJ
# 7         7     10                Little Mix  3e7awlrlDSwF3iM0WBjGMp
# 8         8     14                        U2  51Blml2LZPmy7TTiAg47vQ
# 9         9     16                  Don Omar  33ScadVnbm2X8kkUqOkC6Z
# 10       10     17           The Local Train  7b6Ui7JVaBDEfZB9k6nHL0
# 11       11     20               Cheat Codes  7DMveApC7UnC2NPfPvlHSU
# 12       12     21                 Vance Joy  10exVja0key0uqUkk6LJRT
# 13       13     22               OneRepublic  5Pwc4xIPtQLFEnJriah9YJ
# 14       14     24              Daddy Yankee  4VMYDCV2IEDYJArk749S6m
# 15       15     25              Shawn Mendes  7n2wHs1TKAczGzO7Dd2rGr
# 16       16     29              Fall Out Boy  4UXqAaa6dQYAk18Lv7PEgX
# 17       17     30             The Lumineers  16oZKvXb6WkQlVAjwo2Wbg
# 18       18     32                     AC/DC  711MCceyCBcFnzjGY4Q7Un
# 19       19     33                Ed Sheeran  6eUKZXaKkcviH0Ku9w2n3V
# 20       20     35                     Oasis  2DaxqgrOhkeH0fpeiQq2f4
# 21       21     37              Charlie Puth  6VuMaDnrHyPL1p4EHjYLi7
# 22       22     39       Panic! At The Disco  20JZFwl6HVl6yg8a4H3ZqK
# 23       23     43            Lynyrd Skynyrd  4MVyzYMgTwdP7Z49wAZHx0
# 24       24     44  Anand Bhaskar Collective  45m11y8OUyx5EgHiKvEC3c
# 25       25     50               George Ezra  2ysnwxxNtSgbb9t1m2Ur4j
# 26       26     51                      CNCO  0eecdvMrqBftK0M1VKhaF4
# 27       27     52            Jonas Brothers  7gOdHgIoIKoe4i9Tta6qdD
# 28       28     55                  Sam Hunt  2kucQ9jQwuD8jWdtR9Ef38
# 29       29     56                    Hozier  2FXC3k01G6Gw61bmprjgqS
# 30       30     58              Arijit Singh  4YRxDV8wJFPHPTeXepOstw
# 31       31     61                      DNCE  6T5tfhQCknKG4UnH90qGnz
# 32       32     63              All Time Low  46gyXjRIvN1NL1eCB8GBxo
# 33       33     69               Niall Horan  1Hsdzj7Dlq2I7tHP7501T4
# 34       34     70             One Direction  4AK6F7OLvEQ5QYCBNiQWHq
#
#                               track
# 0                    One More Night
# 1                        In The End
# 2                       Basket Case
# 3          I Knew You Were Trouble.
# 4                 Tennessee Whiskey
# 5                         R U Mine?
# 6                   Save Your Tears
# 7                             Touch
# 8                     Beautiful Day
# 9                      Danza Kuduro
# 10                         Dil Mere
# 11       Only You (with Little Mix)
# 12                          Riptide
# 13                          Secrets
# 14                             Dura
# 15                         Señorita
# 16                   Fourth Of July
# 17                          Ophelia
# 18                  Highway to Hell
# 19  Beautiful People (feat. Khalid)
# 20          Wonderwall - Remastered
# 21                        Attention
# 22       I Write Sins Not Tragedies
# 23               Sweet Home Alabama
# 24                           Malhar
# 25                         Budapest
# 26          Reggaetón Lento (Remix)
# 27              What A Man Gotta Do
# 28            Body Like A Back Road
# 29                Take Me To Church
# 30            Ghungroo (From "War")
# 31                       Truthfully
# 32              Last Young Renegade
# 33                     Seeing Blind
# 34                 Story of My Life
