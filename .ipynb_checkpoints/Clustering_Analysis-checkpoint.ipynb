# %%
import spotipy.util as util
import spotipy
import pandas as pd
import numpy as np
import json
import time
import sys
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
import plotly.graph_objects as go
from collections import OrderedDict
from math import log
import calmap

# %%
import plotly
from plotly.offline import download_plotlyjs, init_notebook_mode,plot,iplot

#plotly setup
init_notebook_mode(connected=True)

pd.set_option('display.max_colwidth', None)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Generate token - If generated it uses the existing
username = '9cjfei8bx9vq78vel4odrjd3y'
client_id ='f2018fb393c2424dba2844c31e8e2c18'
client_secret = 'f4bb9567dafc4625877be647542fd919'
redirect_uri = 'http://localhost:7777/callback'
scope = 'user-read-recently-played user-top-read playlist-read-private user-library-read user-follow-read'

token = util.prompt_for_user_token(username=username, 
scope=scope, 
client_id=client_id,   
client_secret=client_secret,     
redirect_uri=redirect_uri)

sp = spotipy.Spotify(auth=token)

# %%
#Get ID for song
import requests
def get_id(track_name: str,artist_name: str, token: str) -> str:
    headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': f'Bearer ' + token,
    }
    params = [
    ('q', track_name + ' ' + artist_name),
    ('type', 'track'),
    ]
    try:
        response = requests.get('https://api.spotify.com/v1/search', 
                    headers = headers, params = params, timeout = 5)
        json = response.json()
        #print(json)
        first_result = json['tracks']['items'][0]
        #print(first_result)
        track_id = first_result['id']
        return track_id
    except:
        return None

# %%
# Get features using track-id
def get_features(track_id: str, token: str) -> dict:
    sp = spotipy.Spotify(auth=token)
    try:
        features = sp.audio_features([track_id])
        #print(features)
        return features[0]
    except:
        return None

# %%
#Get Artist ID for song
import requests
def get_artist_id(track_name: str,artist_name: str, token: str) -> str:
    headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': f'Bearer ' + token,
    }
    params = [
    ('q', track_name + ' ' + artist_name),
    ('type', 'track'),
    ]
    try:
        response = requests.get('https://api.spotify.com/v1/search', 
                    headers = headers, params = params, timeout = 5)
        json = response.json()
        #print(json)
        first_result = json['tracks']['items'][0]
        #print(first_result)
        id0 = first_result['artists']
        id1 = id0[0] 
        artist_id = id1['id']
        return artist_id
    except:
        return None

# %%
#### Getting list of artist #####
'''top = pd.read_pickle('top_features.pkl')

artist_list = pd.DataFrame(top.iloc[:,16])
artist_list['id'] = 'id'
artist_list['track'] = top.iloc[:,0]
#artist_list

artist_list['id'] = 'id'
row,col = artist_list.shape 
for i in range(0,row):
    artist_list.iloc[i,1] = get_artist_id(artist_list.iloc[i,2],artist_list.iloc[i,0],token)
#artist_list

artist_list = artist_list.drop_duplicates(subset='id')
artist_list = artist_list.reset_index(drop ='True')
#artist_list

#artist_list = artist_list.rename(columns={'analysis_url':'artist'})
#artist_list

artist_list.to_pickle(r'C:\Users\hp\Documents\ProjectOne\Created_Features\artist_list.pkl')

'''
# Out:
#   File "<ipython-input-7-4f0ec3b5287d>", line 24
#     '''
#       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 575-576: truncated \UXXXXXXXX escape

# %%
#Future Use
artist_list = pd.read_pickle(r'Created_Features\artist_list.pkl')

# %%
artist_list['album_id'] ='0'
for i in range(0,35):
    artist_list.iloc[i,3] = sp.artist_top_tracks(artist_list.iloc[i,1])['tracks'][2]['album']['id']
artist_list
# Out:
#                       artist                      id  \
# 0                   Maroon 5  04gDigrS5kc9YWfZHwBETP
# 1          Black Veil Brides  6O7MpKrY91vlCd4Osi6XKs
# 2                  Green Day  7oPftvlwr6VrsViSDV7fJY
# 3               Taylor Swift  06HL4z0CvFAxyc27GXpf02
# 4            Chris Stapleton  4YLtscXsxbVgi031ovDDdh
# 5             Arctic Monkeys  7Ln80lUS6He07XvHI8qqHH
# 6                 The Weeknd  1Xyo4u8uXC1ZmMpatF05PJ
# 7                 Little Mix  3e7awlrlDSwF3iM0WBjGMp
# 8                         U2  51Blml2LZPmy7TTiAg47vQ
# 9                   Don Omar  33ScadVnbm2X8kkUqOkC6Z
# 10           The Local Train  7b6Ui7JVaBDEfZB9k6nHL0
# 11               Cheat Codes  7DMveApC7UnC2NPfPvlHSU
# 12                 Vance Joy  10exVja0key0uqUkk6LJRT
# 13               OneRepublic  5Pwc4xIPtQLFEnJriah9YJ
# 14              Daddy Yankee  4VMYDCV2IEDYJArk749S6m
# 15              Shawn Mendes  7n2wHs1TKAczGzO7Dd2rGr
# 16              Fall Out Boy  4UXqAaa6dQYAk18Lv7PEgX
# 17             The Lumineers  16oZKvXb6WkQlVAjwo2Wbg
# 18                     AC/DC  711MCceyCBcFnzjGY4Q7Un
# 19                Ed Sheeran  6eUKZXaKkcviH0Ku9w2n3V
# 20                     Oasis  2DaxqgrOhkeH0fpeiQq2f4
# 21              Charlie Puth  6VuMaDnrHyPL1p4EHjYLi7
# 22       Panic! At The Disco  20JZFwl6HVl6yg8a4H3ZqK
# 23            Lynyrd Skynyrd  4MVyzYMgTwdP7Z49wAZHx0
# 24  Anand Bhaskar Collective  45m11y8OUyx5EgHiKvEC3c
# 25               George Ezra  2ysnwxxNtSgbb9t1m2Ur4j
# 26                      CNCO  0eecdvMrqBftK0M1VKhaF4
# 27            Jonas Brothers  7gOdHgIoIKoe4i9Tta6qdD
# 28                  Sam Hunt  2kucQ9jQwuD8jWdtR9Ef38
# 29                    Hozier  2FXC3k01G6Gw61bmprjgqS
# 30              Arijit Singh  4YRxDV8wJFPHPTeXepOstw
# 31                      DNCE  6T5tfhQCknKG4UnH90qGnz
# 32              All Time Low  46gyXjRIvN1NL1eCB8GBxo
# 33               Niall Horan  1Hsdzj7Dlq2I7tHP7501T4
# 34             One Direction  4AK6F7OLvEQ5QYCBNiQWHq
#
#                               track                album_id
# 0                    One More Night  2Auw0pTT6EcQdvHNimhLQI
# 1                        In The End  3iTUq3CfkKcD5ZN4zgcDIA
# 2                       Basket Case  5dN7F9DV0Qg1XRdIgW8rke
# 3          I Knew You Were Trouble.  2fenSS68JI1h4Fo296JfGr
# 4                 Tennessee Whiskey  7lxHnls3yQNl8B9bILmHj7
# 5                         R U Mine?  78bpIziExqiI9qztvNFlQu
# 6                   Save Your Tears  2ODvWsOgouMbaA5xf0RkJe
# 7                             Touch  4bzVI1FElc13HQagFR7S1W
# 8                     Beautiful Day  0ta5VdkJcpdVnNrn7g4cZe
# 9                      Danza Kuduro  4vOvr0tdZWoIGjnHe9jLqz
# 10                         Dil Mere  7ouN1RiK4NRenRCnrGkA1Z
# 11       Only You (with Little Mix)  242iBDjn57roEbUdUmgKPV
# 12                          Riptide  5S9b8euumqMhQbMk0zzQdH
# 13                          Secrets  2bbhW5ifCwOYM8DMkqoYBF
# 14                             Dura  7JtT7OyWM8BnIS5FXXPMKg
# 15                         Señorita  0xzScN8P3hQAz3BT3YYX5w
# 16                   Fourth Of July  5nkUSlIhtoJZMOUlB0sNCp
# 17                          Ophelia  2zbTrm2pIAErzFSopinkbN
# 18                  Highway to Hell  4vu7F6h90Br1ZtYYaqfITy
# 19  Beautiful People (feat. Khalid)  3oIFxDIo2fwuk4lwCmFZCx
# 20          Wonderwall - Remastered  1Esiu8FNzQ8lgZWy6p0DXD
# 21                        Attention  4D9M4nzQ9kvchgxyQyymtW
# 22       I Write Sins Not Tragedies  4M07HWIlZr7zoXoxDHR5mz
# 23               Sweet Home Alabama  6DExt1eX4lflLacVjHHbOs
# 24                           Malhar  2tirSRVQqyXaTw67dAgYqy
# 25                         Budapest  2NaulYO6lGXTyIzWTJvRJj
# 26          Reggaetón Lento (Remix)  0YCyFUN3ihGbP2x9C09NF6
# 27              What A Man Gotta Do  0i96PtPJV65ddxsfMfo45F
# 28            Body Like A Back Road  0V7c0hnrLUFJyHNtjiAT2E
# 29                Take Me To Church  2c7gFThUYyo2t6ogAgIYNw
# 30            Ghungroo (From "War")  6IXfWhC7omotM4lt0ROmEr
# 31                       Truthfully  3Wv4X8OA65pGpFzBkuUgAh
# 32              Last Young Renegade  7tY7NcC2gKTxXsTJM6zK5I
# 33                     Seeing Blind  5gdoRB1AUsGnScCuZ8gmPp
# 34                 Story of My Life  4gCNyS7pidfK3rKWhB3JOY

# %%
for s in artist_list:
    print(s[3])
# Out:
# i
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-bd9ff4238fb8> in <module>
#       1 for s in artist_list:
# ----> 2     print(s[3])
#
# IndexError: string index out of range

# %%
f = (fus['items'])
len(f)
f1 = f[0]
f1['name']
# Out:
# 'New Religion'

# %%
songs=[]
for k in range(0,34):
    fus = sp.album_tracks(artist_list.iloc[k,3])
    f = (fus['items'])
    for i in range(0,len(f)):
        f1 = f[i]
        songs.append([f1['name'], artist_list.iloc[k,0], 'abc'])

songs
# Out:
# [['Maps', 'Maroon 5', 'abc'],
#  ['Animals', 'Maroon 5', 'abc'],
#  ['It Was Always You', 'Maroon 5', 'abc'],
#  ['Unkiss Me', 'Maroon 5', 'abc'],
#  ['Sugar', 'Maroon 5', 'abc'],
#  ['Leaving California', 'Maroon 5', 'abc'],
#  ['In Your Pocket', 'Maroon 5', 'abc'],
#  ['New Love', 'Maroon 5', 'abc'],
#  ['Coming Back For You', 'Maroon 5', 'abc'],
#  ['Feelings', 'Maroon 5', 'abc'],
#  ['My Heart Is Open', 'Maroon 5', 'abc'],
#  ['This Summer', 'Maroon 5', 'abc'],
#  ['New Religion', 'Black Veil Brides', 'abc'],
#  ['Set The World On Fire', 'Black Veil Brides', 'abc'],
#  ['Fallen Angels', 'Black Veil Brides', 'abc'],
#  ["Love Isn't Always Fair", 'Black Veil Brides', 'abc'],
#  ['God Bless You', 'Black Veil Brides', 'abc'],
#  ['Rebel Love Song', 'Black Veil Brides', 'abc'],
#  ['Saviour', 'Black Veil Brides', 'abc'],
#  ['The Legacy', 'Black Veil Brides', 'abc'],
#  ['Die For You', 'Black Veil Brides', 'abc'],
#  ['Ritual', 'Black Veil Brides', 'abc'],
#  ['Youth & Whisky', 'Black Veil Brides', 'abc'],
#  ['American Idiot', 'Green Day', 'abc'],
#  ['Jesus of Suburbia', 'Green Day', 'abc'],
#  ['Holiday / Boulevard of Broken Dreams', 'Green Day', 'abc'],
#  ['Are We the Waiting / St. Jimmy', 'Green Day', 'abc'],
#  ["Give Me Novacaine / She's a Rebel", 'Green Day', 'abc'],
#  ['Extraordinary Girl / Letterbomb', 'Green Day', 'abc'],
#  ['Wake Me up When September Ends', 'Green Day', 'abc'],
#  ['Homecoming', 'Green Day', 'abc'],
#  ['Whatsername', 'Green Day', 'abc'],
#  ['the 1', 'Taylor Swift', 'abc'],
#  ['cardigan', 'Taylor Swift', 'abc'],
#  ['the last great american dynasty', 'Taylor Swift', 'abc'],
#  ['exile (feat. Bon Iver)', 'Taylor Swift', 'abc'],
#  ['my tears ricochet', 'Taylor Swift', 'abc'],
#  ['mirrorball', 'Taylor Swift', 'abc'],
#  ['seven', 'Taylor Swift', 'abc'],
#  ['august', 'Taylor Swift', 'abc'],
#  ['this is me trying', 'Taylor Swift', 'abc'],
#  ['illicit affairs', 'Taylor Swift', 'abc'],
#  ['invisible string', 'Taylor Swift', 'abc'],
#  ['mad woman', 'Taylor Swift', 'abc'],
#  ['epiphany', 'Taylor Swift', 'abc'],
#  ['betty', 'Taylor Swift', 'abc'],
#  ['peace', 'Taylor Swift', 'abc'],
#  ['hoax', 'Taylor Swift', 'abc'],
#  ['Traveller', 'Chris Stapleton', 'abc'],
#  ['Fire Away', 'Chris Stapleton', 'abc'],
#  ['Tennessee Whiskey', 'Chris Stapleton', 'abc'],
#  ['Parachute', 'Chris Stapleton', 'abc'],
#  ['Whiskey And You', 'Chris Stapleton', 'abc'],
#  ['Nobody To Blame', 'Chris Stapleton', 'abc'],
#  ['More Of You', 'Chris Stapleton', 'abc'],
#  ['When The Stars Come Out', 'Chris Stapleton', 'abc'],
#  ["Daddy Doesn't Pray Anymore", 'Chris Stapleton', 'abc'],
#  ['Might As Well Get Stoned', 'Chris Stapleton', 'abc'],
#  ['Was It 26', 'Chris Stapleton', 'abc'],
#  ['The Devil Named Music', 'Chris Stapleton', 'abc'],
#  ['Outlaw State Of Mind', 'Chris Stapleton', 'abc'],
#  ['Sometimes I Cry', 'Chris Stapleton', 'abc'],
#  ['Do I Wanna Know?', 'Arctic Monkeys', 'abc'],
#  ['R U Mine?', 'Arctic Monkeys', 'abc'],
#  ['One For The Road', 'Arctic Monkeys', 'abc'],
#  ['Arabella', 'Arctic Monkeys', 'abc'],
#  ['I Want It All', 'Arctic Monkeys', 'abc'],
#  ['No. 1 Party Anthem', 'Arctic Monkeys', 'abc'],
#  ['Mad Sounds', 'Arctic Monkeys', 'abc'],
#  ['Fireside', 'Arctic Monkeys', 'abc'],
#  ["Why'd You Only Call Me When You're High?", 'Arctic Monkeys', 'abc'],
#  ['Snap Out Of It', 'Arctic Monkeys', 'abc'],
#  ['Knee Socks', 'Arctic Monkeys', 'abc'],
#  ['I Wanna Be Yours', 'Arctic Monkeys', 'abc'],
#  ['Starboy', 'The Weeknd', 'abc'],
#  ['Party Monster', 'The Weeknd', 'abc'],
#  ['False Alarm', 'The Weeknd', 'abc'],
#  ['Reminder', 'The Weeknd', 'abc'],
#  ['Rockin’', 'The Weeknd', 'abc'],
#  ['Secrets', 'The Weeknd', 'abc'],
#  ['True Colors', 'The Weeknd', 'abc'],
#  ['Stargirl Interlude', 'The Weeknd', 'abc'],
#  ['Sidewalks', 'The Weeknd', 'abc'],
#  ['Six Feet Under', 'The Weeknd', 'abc'],
#  ['Love To Lay', 'The Weeknd', 'abc'],
#  ['A Lonely Night', 'The Weeknd', 'abc'],
#  ['Attention', 'The Weeknd', 'abc'],
#  ['Ordinary Life', 'The Weeknd', 'abc'],
#  ['Nothing Without You', 'The Weeknd', 'abc'],
#  ['All I Know', 'The Weeknd', 'abc'],
#  ['Die For You', 'The Weeknd', 'abc'],
#  ['I Feel It Coming', 'The Weeknd', 'abc'],
#  ['Black Magic', 'Little Mix', 'abc'],
#  ['Love Me Like You', 'Little Mix', 'abc'],
#  ['Weird People', 'Little Mix', 'abc'],
#  ['Secret Love Song (feat. Jason Derulo)', 'Little Mix', 'abc'],
#  ['Hair', 'Little Mix', 'abc'],
#  ['Grown', 'Little Mix', 'abc'],
#  ['I Love You', 'Little Mix', 'abc'],
#  ['OMG', 'Little Mix', 'abc'],
#  ['Lightning', 'Little Mix', 'abc'],
#  ['A.D.I.D.A.S.', 'Little Mix', 'abc'],
#  ['Love Me or Leave Me', 'Little Mix', 'abc'],
#  ['The End', 'Little Mix', 'abc'],
#  ["I Won't", 'Little Mix', 'abc'],
#  ['Secret Love Song, Pt. II', 'Little Mix', 'abc'],
#  ['Clued Up', 'Little Mix', 'abc'],
#  ['The Beginning', 'Little Mix', 'abc'],
#  ['Zoo Station', 'U2', 'abc'],
#  ['Even Better Than The Real Thing', 'U2', 'abc'],
#  ['One', 'U2', 'abc'],
#  ['Until The End Of The World', 'U2', 'abc'],
#  ["Who's Gonna Ride Your Wild Horses", 'U2', 'abc'],
#  ['So Cruel', 'U2', 'abc'],
#  ['The Fly', 'U2', 'abc'],
#  ['Mysterious Ways', 'U2', 'abc'],
#  ["Tryin' To Throw Your Arms Around The World", 'U2', 'abc'],
#  ['Ultra Violet (Light My Way)', 'U2', 'abc'],
#  ['Acrobat', 'U2', 'abc'],
#  ['Love Is Blindness', 'U2', 'abc'],
#  ['Lady With The Spinning Head (UV1)', 'U2', 'abc'],
#  ['Blow Your House Down', 'U2', 'abc'],
#  ['Salomé', 'U2', 'abc'],
#  ['Even Better Than The Real Thing - Single Version', 'U2', 'abc'],
#  ['Satellite Of Love', 'U2', 'abc'],
#  ["Who's Gonna Ride Your Wild Horses - Temple Bar Remix", 'U2', 'abc'],
#  ['Paint It Black', 'U2', 'abc'],
#  ['Even Better Than The Real Thing - Fish Out Of Water Remix', 'U2', 'abc'],
#  ['Mysterious Ways - The Perfecto Mix', 'U2', 'abc'],
#  ['Night And Day - Steel String Remix', 'U2', 'abc'],
#  ['The Lounge Fly Mix', 'U2', 'abc'],
#  ['Fortunate Son', 'U2', 'abc'],
#  ['Alex Descends Into Hell For A Bottle Of Milk / Korova 1', 'U2', 'abc'],
#  ['Where Did It All Go Wrong?', 'U2', 'abc'],
#  ['Intro', 'Don Omar', 'abc'],
#  ['Dale Don Mas Duro', 'Don Omar', 'abc'],
#  ['Intocable', 'Don Omar', 'abc'],
#  ['Dile', 'Don Omar', 'abc'],
#  ['Aunque Te Fuiste', 'Don Omar', 'abc'],
#  ['La Noche Esta Buena', 'Don Omar', 'abc'],
#  ['Provócandome', 'Don Omar', 'abc'],
#  ['Caserios #2', 'Don Omar', 'abc'],
#  ['Quien La Vio Llorar', 'Don Omar', 'abc'],
#  ['Perreando - Remix', 'Don Omar', 'abc'],
#  ['Tu Cuerpo Me Arrebata', 'Don Omar', 'abc'],
#  ['La Recompenza', 'Don Omar', 'abc'],
#  ['Guayaquil', 'Don Omar', 'abc'],
#  ['Intocable - Remix', 'Don Omar', 'abc'],
#  ['Dale Don Dale', 'Don Omar', 'abc'],
#  ['Gustaakh', 'The Local Train', 'abc'],
#  ['Dilnawaz', 'The Local Train', 'abc'],
#  ['Khudi', 'The Local Train', 'abc'],
#  ['Aaftaab', 'The Local Train', 'abc'],
#  ['Mere Yaar', 'The Local Train', 'abc'],
#  ['Mizaaj', 'The Local Train', 'abc'],
#  ['Aakhri Salaam', 'The Local Train', 'abc'],
#  ['Vaaqif', 'The Local Train', 'abc'],
#  ['On My Life', 'Cheat Codes', 'abc'],
#  ['Winds of Change', 'Vance Joy', 'abc'],
#  ['Mess Is Mine', 'Vance Joy', 'abc'],
#  ['Wasted Time', 'Vance Joy', 'abc'],
#  ['Riptide', 'Vance Joy', 'abc'],
#  ['Who Am I', 'Vance Joy', 'abc'],
#  ['From Afar', 'Vance Joy', 'abc'],
#  ['We All Die Trying to Get It Right', 'Vance Joy', 'abc'],
#  ['Georgia', 'Vance Joy', 'abc'],
#  ['Red Eye', 'Vance Joy', 'abc'],
#  ['First Time', 'Vance Joy', 'abc'],
#  ['All I Ever Wanted', 'Vance Joy', 'abc'],
#  ['Best That I Can', 'Vance Joy', 'abc'],
#  ['My Kind of Man', 'Vance Joy', 'abc'],
#  ['Fire and the Flood', 'Vance Joy', 'abc'],
#  ['Straight into Your Arms - Bonus Track Version', 'Vance Joy', 'abc'],
#  ['Counting Stars', 'OneRepublic', 'abc'],
#  ['Love Runs Out', 'OneRepublic', 'abc'],
#  ['If I Lose Myself', 'OneRepublic', 'abc'],
#  ['Feel Again', 'OneRepublic', 'abc'],
#  ['What You Wanted', 'OneRepublic', 'abc'],
#  ['I Lived', 'OneRepublic', 'abc'],
#  ['Light It Up', 'OneRepublic', 'abc'],
#  ['Can’t Stop', 'OneRepublic', 'abc'],
#  ['Au Revoir', 'OneRepublic', 'abc'],
#  ['Burning Bridges', 'OneRepublic', 'abc'],
#  ['Something I Need', 'OneRepublic', 'abc'],
#  ['Preacher', 'OneRepublic', 'abc'],
#  ["Don't Look Down", 'OneRepublic', 'abc'],
#  ['Life In Color', 'OneRepublic', 'abc'],
#  ['If I Lose Myself - Alesso vs OneRepublic', 'OneRepublic', 'abc'],
#  ['No Llores Mujer', 'Daddy Yankee', 'abc'],
#  ['Somo o No Somos', 'Daddy Yankee', 'abc'],
#  ['Reggaetonera', 'Daddy Yankee', 'abc'],
#  ['Jangueo', 'Daddy Yankee', 'abc'],
#  ['Hasta Que Dios Diga', 'Daddy Yankee', 'abc'],
#  ['Narcos', 'Daddy Yankee', 'abc'],
#  ['Fútbol & Rumba (feat. Enrique Iglesias)', 'Daddy Yankee', 'abc'],
#  ['Que Se Joda', 'Daddy Yankee', 'abc'],
#  ['Ferrari', 'Daddy Yankee', 'abc'],
#  ['El Manual', 'Daddy Yankee', 'abc'],
#  ['Antes y Después', 'Daddy Yankee', 'abc'],
#  ['¿Los Hombres No Lloran?', 'Daddy Yankee', 'abc'],
#  ['Así Soy Yo', 'Daddy Yankee', 'abc'],
#  ['El Problema', 'Daddy Yankee', 'abc'],
#  ['Bandido', 'Daddy Yankee', 'abc'],
#  ['Rifles Rusos', 'Daddy Yankee', 'abc'],
#  ['Mi Vieja', 'Daddy Yankee', 'abc'],
#  ['Nubes Negras', 'Daddy Yankee', 'abc'],
#  ['Tocándote', 'Daddy Yankee', 'abc'],
#  ['Estrés Postraumático', 'Daddy Yankee', 'abc'],
#  ['Secreto', 'Daddy Yankee', 'abc'],
#  ['China', 'Daddy Yankee', 'abc'],
#  ['Señorita', 'Shawn Mendes', 'abc'],
#  ['Lost In Japan', 'Shawn Mendes', 'abc'],
#  ["If I Can't Have You", 'Shawn Mendes', 'abc'],
#  ['In My Blood', 'Shawn Mendes', 'abc'],
#  ["Fallin' All In You", 'Shawn Mendes', 'abc'],
#  ['Where Were You In The Morning?', 'Shawn Mendes', 'abc'],
#  ['Nervous', 'Shawn Mendes', 'abc'],
#  ['Like To Be You (feat. Julia Michaels)', 'Shawn Mendes', 'abc'],
#  ['Particular Taste', 'Shawn Mendes', 'abc'],
#  ['Because I Had You', 'Shawn Mendes', 'abc'],
#  ['Why', 'Shawn Mendes', 'abc'],
#  ['Youth (feat. Khalid)', 'Shawn Mendes', 'abc'],
#  ['Perfectly Wrong', 'Shawn Mendes', 'abc'],
#  ['Mutual', 'Shawn Mendes', 'abc'],
#  ['Queen', 'Shawn Mendes', 'abc'],
#  ["When You're Ready", 'Shawn Mendes', 'abc'],
#  ["Our Lawyer Made Us Change The Name Of This Song So We Wouldn't Get Sued",
#   'Fall Out Boy',
#   'abc'],
#  ['Of All The Gin Joints In All The World', 'Fall Out Boy', 'abc'],
#  ['Dance, Dance', 'Fall Out Boy', 'abc'],
#  ["Sugar, We're Goin Down", 'Fall Out Boy', 'abc'],
#  ['Nobody Puts Baby In The Corner', 'Fall Out Boy', 'abc'],
#  ["I've Got A Dark Alley And A Bad Idea That Says You Should Shut Your Mouth (Summer Song)",
#   'Fall Out Boy',
#   'abc'],
#  ['7 Minutes In Heaven (Atavan Halen)', 'Fall Out Boy', 'abc'],
#  ['Sophomore Slump Or Comeback Of The Year', 'Fall Out Boy', 'abc'],
#  ['Champagne For My Real Friends, Real Pain For My Sham Friends',
#   'Fall Out Boy',
#   'abc'],
#  ['I Slept With Someone In Fall Out Boy And All I Got Was This Stupid Song Written About Me',
#   'Fall Out Boy',
#   'abc'],
#  ['A Little Less Sixteen Candles, A Little More "Touch Me"',
#   'Fall Out Boy',
#   'abc'],
#  ['Get Busy Living Or Get Busy Dying (Do Your Part To Save The Scene And Stop Going To Shows)',
#   'Fall Out Boy',
#   'abc'],
#  ['XO', 'Fall Out Boy', 'abc'],
#  ['Sleep On The Floor', 'The Lumineers', 'abc'],
#  ['Ophelia', 'The Lumineers', 'abc'],
#  ['Cleopatra', 'The Lumineers', 'abc'],
#  ['Gun Song', 'The Lumineers', 'abc'],
#  ['Angela', 'The Lumineers', 'abc'],
#  ['In The Light', 'The Lumineers', 'abc'],
#  ['Gale Song', 'The Lumineers', 'abc'],
#  ['Long Way From Home', 'The Lumineers', 'abc'],
#  ['Sick In The Head', 'The Lumineers', 'abc'],
#  ['My Eyes', 'The Lumineers', 'abc'],
#  ['Patience', 'The Lumineers', 'abc'],
#  ['Thunderstruck', 'AC/DC', 'abc'],
#  ['Fire Your Guns', 'AC/DC', 'abc'],
#  ['Moneytalks', 'AC/DC', 'abc'],
#  ['The Razors Edge', 'AC/DC', 'abc'],
#  ['Mistress for Christmas', 'AC/DC', 'abc'],
#  ['Rock Your Heart Out', 'AC/DC', 'abc'],
#  ['Are You Ready', 'AC/DC', 'abc'],
#  ['Got You by the Balls', 'AC/DC', 'abc'],
#  ['Shot of Love', 'AC/DC', 'abc'],
#  ["Let's Make It", 'AC/DC', 'abc'],
#  ['Goodbye and Good Riddance to Bad Luck', 'AC/DC', 'abc'],
#  ['If You Dare', 'AC/DC', 'abc'],
#  ['Beautiful People (feat. Khalid)', 'Ed Sheeran', 'abc'],
#  ['South of the Border (feat. Camila Cabello & Cardi B)', 'Ed Sheeran', 'abc'],
#  ['Cross Me (feat. Chance the Rapper & PnB Rock)', 'Ed Sheeran', 'abc'],
#  ['Take Me Back to London (feat. Stormzy)', 'Ed Sheeran', 'abc'],
#  ['Best Part of Me (feat. YEBBA)', 'Ed Sheeran', 'abc'],
#  ["I Don't Care (with Justin Bieber)", 'Ed Sheeran', 'abc'],
#  ['Antisocial (with Travis Scott)', 'Ed Sheeran', 'abc'],
#  ['Remember The Name (feat. Eminem & 50 Cent)', 'Ed Sheeran', 'abc'],
#  ['Feels (feat. Young Thug & J Hus)', 'Ed Sheeran', 'abc'],
#  ['Put It All on Me (feat. Ella Mai)', 'Ed Sheeran', 'abc'],
#  ['Nothing On You (feat. Paulo Londra & Dave)', 'Ed Sheeran', 'abc'],
#  ["I Don't Want Your Money (feat. H.E.R.)", 'Ed Sheeran', 'abc'],
#  ['1000 Nights (feat. Meek Mill & A Boogie Wit da Hoodie)',
#   'Ed Sheeran',
#   'abc'],
#  ['Way To Break My Heart (feat. Skrillex)', 'Ed Sheeran', 'abc'],
#  ['BLOW (with Chris Stapleton & Bruno Mars)', 'Ed Sheeran', 'abc'],
#  ['The Hindu Times', 'Oasis', 'abc'],
#  ['Force Of Nature', 'Oasis', 'abc'],
#  ['Hung In A Bad Place', 'Oasis', 'abc'],
#  ['Stop Crying Your Heart Out', 'Oasis', 'abc'],
#  ['Songbird', 'Oasis', 'abc'],
#  ['Little By Little', 'Oasis', 'abc'],
#  ['A Quick Peep', 'Oasis', 'abc'],
#  ['[Probably] All In The Mind', 'Oasis', 'abc'],
#  ['She Is Love', 'Oasis', 'abc'],
#  ['Born On A Different Cloud', 'Oasis', 'abc'],
#  ['Better Man/The Cage', 'Oasis', 'abc'],
#  ["Summer Feelings (feat. Charlie Puth) - From 'SCOOB!' The Album",
#   'Charlie Puth',
#   'abc'],
#  ['All Is Found', 'Panic! At The Disco', 'abc'],
#  ['Some Things Never Change', 'Panic! At The Disco', 'abc'],
#  ['Into the Unknown', 'Panic! At The Disco', 'abc'],
#  ['When I Am Older', 'Panic! At The Disco', 'abc'],
#  ['Reindeer(s) Are Better Than People (Cont.)', 'Panic! At The Disco', 'abc'],
#  ['Lost in the Woods', 'Panic! At The Disco', 'abc'],
#  ['Show Yourself', 'Panic! At The Disco', 'abc'],
#  ['The Next Right Thing', 'Panic! At The Disco', 'abc'],
#  ['Into the Unknown - Panic! At The Disco Version',
#   'Panic! At The Disco',
#   'abc'],
#  ['All Is Found - Kacey Musgraves Version', 'Panic! At The Disco', 'abc'],
#  ['Lost in the Woods - Weezer Version', 'Panic! At The Disco', 'abc'],
#  ['All Is Found (Lullaby Ending) - Outtake', 'Panic! At The Disco', 'abc'],
#  ['Home - Outtake', 'Panic! At The Disco', 'abc'],
#  ['I Seek the Truth - Outtake', 'Panic! At The Disco', 'abc'],
#  ['Unmeltable Me - Outtake', 'Panic! At The Disco', 'abc'],
#  ['Get This Right - Outtake', 'Panic! At The Disco', 'abc'],
#  ['All Is Found - Instrumental', 'Panic! At The Disco', 'abc'],
#  ['Some Things Never Change - Instrumental', 'Panic! At The Disco', 'abc'],
#  ['Into the Unknown - Instrumental', 'Panic! At The Disco', 'abc'],
#  ['When I Am Older - Instrumental', 'Panic! At The Disco', 'abc'],
#  ['Reindeer(s) Are Better Than People (Cont.) - Instrumental',
#   'Panic! At The Disco',
#   'abc'],
#  ['Lost in the Woods - Instrumental', 'Panic! At The Disco', 'abc'],
#  ['Show Yourself - Instrumental', 'Panic! At The Disco', 'abc'],
#  ['The Next Right Thing - Instrumental', 'Panic! At The Disco', 'abc'],
#  ['Into the Unknown - Panic! At The Disco Version/Instrumental',
#   'Panic! At The Disco',
#   'abc'],
#  ['All Is Found - Kacey Musgraves Version/Instrumental',
#   'Panic! At The Disco',
#   'abc'],
#  ['Lost in the Woods - Weezer Version/Instrumental',
#   'Panic! At The Disco',
#   'abc'],
#  ['Introduction', 'Panic! At The Disco', 'abc'],
#  ['The Northuldra', 'Panic! At The Disco', 'abc'],
#  ['Sisters', 'Panic! At The Disco', 'abc'],
#  ['Exodus', 'Panic! At The Disco', 'abc'],
#  ['The Mist', 'Panic! At The Disco', 'abc'],
#  ['Wind', 'Panic! At The Disco', 'abc'],
#  ["Iduna's Scarf", 'Panic! At The Disco', 'abc'],
#  ['Fire and Ice', 'Panic! At The Disco', 'abc'],
#  ['Earth Giants', 'Panic! At The Disco', 'abc'],
#  ['The Ship', 'Panic! At The Disco', 'abc'],
#  ['River Slide', 'Panic! At The Disco', 'abc'],
#  ['Dark Sea', 'Panic! At The Disco', 'abc'],
#  ['Ghosts of Arendelle Past', 'Panic! At The Disco', 'abc'],
#  ['Gone Too Far', 'Panic! At The Disco', 'abc'],
#  ['Rude Awakening', 'Panic! At The Disco', 'abc'],
#  ['The Flood', 'Panic! At The Disco', 'abc'],
#  ['Reindeer Circle', 'Panic! At The Disco', 'abc'],
#  ['Reunion', 'Panic! At The Disco', 'abc'],
#  ['Epilogue', 'Panic! At The Disco', 'abc'],
#  ["I Ain't The One", 'Lynyrd Skynyrd', 'abc'],
#  ["Tuesday's Gone", 'Lynyrd Skynyrd', 'abc'],
#  ['Gimme Three Steps', 'Lynyrd Skynyrd', 'abc'],
#  ['Simple Man', 'Lynyrd Skynyrd', 'abc'],
#  ["Things Goin' On", 'Lynyrd Skynyrd', 'abc'],
#  ['Mississippi Kid', 'Lynyrd Skynyrd', 'abc'],
#  ['Poison Whiskey', 'Lynyrd Skynyrd', 'abc'],
#  ['Free Bird', 'Lynyrd Skynyrd', 'abc'],
#  ['Main Hoon Zameen', 'Anand Bhaskar Collective', 'abc'],
#  ['Pretty Shining People', 'George Ezra', 'abc'],
#  ["Don't Matter Now", 'George Ezra', 'abc'],
#  ['Get Away', 'George Ezra', 'abc'],
#  ['Shotgun', 'George Ezra', 'abc'],
#  ['Paradise', 'George Ezra', 'abc'],
#  ['All My Love', 'George Ezra', 'abc'],
#  ['Sugarcoat', 'George Ezra', 'abc'],
#  ['Hold My Girl', 'George Ezra', 'abc'],
#  ['Saviour (feat. First Aid Kit)', 'George Ezra', 'abc'],
#  ['Only a Human', 'George Ezra', 'abc'],
#  ['The Beautiful Dream', 'George Ezra', 'abc'],
#  ['Sólo Yo', 'CNCO', 'abc'],
#  ['Hey DJ', 'CNCO', 'abc'],
#  ['Se Vuelve Loca', 'CNCO', 'abc'],
#  ['Mamita', 'CNCO', 'abc'],
#  ['Fiesta en Mi Casa', 'CNCO', 'abc'],
#  ['Noche Inolvidable', 'CNCO', 'abc'],
#  ['Bonita', 'CNCO', 'abc'],
#  ['Estoy Enamorado de Ti', 'CNCO', 'abc'],
#  ['Mala Actitud', 'CNCO', 'abc'],
#  ['Mi Medicina', 'CNCO', 'abc'],
#  ['Fan Enamorada', 'CNCO', 'abc'],
#  ['No Me Sueltes', 'CNCO', 'abc'],
#  ['Demuéstrame', 'CNCO', 'abc'],
#  ['Reggaetón Lento (Remix)', 'CNCO', 'abc'],
#  ['X (with KAROL G)', 'Jonas Brothers', 'abc'],
#  ['Five More Minutes', 'Jonas Brothers', 'abc'],
#  ['Take Your Time', 'Sam Hunt', 'abc'],
#  ['Leave The Night On', 'Sam Hunt', 'abc'],
#  ['House Party', 'Sam Hunt', 'abc'],
#  ['Break Up In A Small Town', 'Sam Hunt', 'abc'],
#  ['Single For The Summer', 'Sam Hunt', 'abc'],
#  ['Ex To See', 'Sam Hunt', 'abc'],
#  ['Make You Miss Me', 'Sam Hunt', 'abc'],
#  ['Cop Car', 'Sam Hunt', 'abc'],
#  ['Raised On It', 'Sam Hunt', 'abc'],
#  ['Speakers', 'Sam Hunt', 'abc'],
#  ['Nina Cried Power (feat. Mavis Staples)', 'Hozier', 'abc'],
#  ['Almost (Sweet Music)', 'Hozier', 'abc'],
#  ['Movement', 'Hozier', 'abc'],
#  ['No Plan', 'Hozier', 'abc'],
#  ['Nobody', 'Hozier', 'abc'],
#  ['To Noise Making (Sing)', 'Hozier', 'abc'],
#  ['As It Was', 'Hozier', 'abc'],
#  ['Shrike', 'Hozier', 'abc'],
#  ['Talk', 'Hozier', 'abc'],
#  ['Be', 'Hozier', 'abc'],
#  ['Dinner & Diatribes', 'Hozier', 'abc'],
#  ['Would That I', 'Hozier', 'abc'],
#  ['Sunlight', 'Hozier', 'abc'],
#  ['Wasteland, Baby!', 'Hozier', 'abc'],
#  ['Shayad', 'Arijit Singh', 'abc'],
#  ['Haan Main Galat', 'Arijit Singh', 'abc'],
#  ['Mehrama', 'Arijit Singh', 'abc'],
#  ['Rahogi Meri', 'Arijit Singh', 'abc'],
#  ['Aur Tanha', 'Arijit Singh', 'abc'],
#  ['Yeh Dooriyan', 'Arijit Singh', 'abc'],
#  ['Shayad - Reprise', 'Arijit Singh', 'abc'],
#  ['Parmeshwara', 'Arijit Singh', 'abc'],
#  ['Dhak Dhak', 'Arijit Singh', 'abc'],
#  ['Haan Tum Ho', 'Arijit Singh', 'abc'],
#  ['Mehrama - Extended', 'Arijit Singh', 'abc'],
#  ['DNCE', 'DNCE', 'abc'],
#  ['Body Moves', 'DNCE', 'abc'],
#  ['Cake By The Ocean', 'DNCE', 'abc'],
#  ['Doctor You', 'DNCE', 'abc'],
#  ['Toothbrush', 'DNCE', 'abc'],
#  ['Blown', 'DNCE', 'abc'],
#  ['Good Day', 'DNCE', 'abc'],
#  ['Almost', 'DNCE', 'abc'],
#  ['Naked', 'DNCE', 'abc'],
#  ['Truthfully', 'DNCE', 'abc'],
#  ['Be Mean', 'DNCE', 'abc'],
#  ['Zoom', 'DNCE', 'abc'],
#  ['Pay My Rent', 'DNCE', 'abc'],
#  ['Unsweet', 'DNCE', 'abc'],
#  ['Weightless', 'All Time Low', 'abc'],
#  ['Break Your Little Heart', 'All Time Low', 'abc'],
#  ["Damned If I Do Ya (Damned If I Don't)", 'All Time Low', 'abc'],
#  ['Lost In Stereo', 'All Time Low', 'abc'],
#  ['Stella', 'All Time Low', 'abc'],
#  ['Sick Little Games', 'All Time Low', 'abc'],
#  ['Hello, Brooklyn', 'All Time Low', 'abc'],
#  ['Walls', 'All Time Low', 'abc'],
#  ['Too Much', 'All Time Low', 'abc'],
#  ['Keep The Change, You Filthy Animal', 'All Time Low', 'abc'],
#  ['A Party Song (The Walk of Shame)', 'All Time Low', 'abc'],
#  ['Therapy', 'All Time Low', 'abc'],
#  ['Poison', 'All Time Low', 'abc'],
#  ['Lost In Stereo (Cobra Starship Suave Suarez Remix)', 'All Time Low', 'abc'],
#  ['Heartbreak Weather', 'Niall Horan', 'abc'],
#  ['Black And White', 'Niall Horan', 'abc'],
#  ['Dear Patience', 'Niall Horan', 'abc'],
#  ['Bend The Rules', 'Niall Horan', 'abc'],
#  ['Small Talk', 'Niall Horan', 'abc'],
#  ['Nice To Meet Ya', 'Niall Horan', 'abc'],
#  ['Put A Little Love On Me', 'Niall Horan', 'abc'],
#  ['Arms Of A Stranger', 'Niall Horan', 'abc'],
#  ['Everywhere', 'Niall Horan', 'abc'],
#  ['Cross Your Mind', 'Niall Horan', 'abc'],
#  ['New Angel', 'Niall Horan', 'abc'],
#  ['No Judgement', 'Niall Horan', 'abc'],
#  ['San Francisco', 'Niall Horan', 'abc'],
#  ['Still', 'Niall Horan', 'abc']]

# %%
for i in range(0,len(songs)):
    songs[i][2] = get_id(songs[i][0],songs[i][1], token)

# %%
all_features = []
for i in range(0,len(songs)):
    track_id = songs[i][2]
    features = get_features(track_id, token)
    if features:
        all_features.append(features)

# %%
all_features = pd.DataFrame(all_features)
songs = pd.DataFrame(songs)

# %%
all_features = all_features.reset_index(drop = False)
all_features
# Out:
#      index  danceability  energy  key  loudness  mode  speechiness  \
# 0        0         0.742   0.713    1    -5.522     0       0.0303
# 1        1         0.279   0.742    4    -6.460     0       0.0898
# 2        2         0.613   0.765   11    -6.582     1       0.0441
# 3        3         0.532   0.599    6    -6.543     1       0.0333
# 4        4         0.748   0.788    1    -7.055     1       0.0334
# ..     ...           ...     ...  ...       ...   ...          ...
# 370    370         0.626   0.795    1    -3.963     1       0.0451
# 371    371         0.639   0.734    9    -3.953     1       0.0331
# 372    372         0.723   0.726    1    -3.835     0       0.0472
# 373    373         0.638   0.725   10    -6.054     1       0.0387
# 374    374         0.416   0.450    3    -6.198     1       0.0269
#
#      acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.020500          0.000000    0.0590    0.879  120.032
# 1        0.000185          0.000000    0.5930    0.328  189.868
# 2        0.082000          0.000001    0.0920    0.299  103.951
# 3        0.007840          0.000000    0.1400    0.113  130.019
# 4        0.059100          0.000000    0.0863    0.884  120.076
# ..            ...               ...       ...      ...      ...
# 370      0.015400          0.000000    0.3500    0.758  123.995
# 371      0.022800          0.000000    0.1260    0.638  108.010
# 372      0.056400          0.000126    0.0570    0.962  100.051
# 373      0.165000          0.000000    0.1520    0.528  136.059
# 374      0.123000          0.000000    0.1130    0.287   97.676
#
#                type                      id  \
# 0    audio_features  7oUHzZKNKUTrlU7DYxhQ7v
# 1    audio_features  3h4T9Bg8OVSUYa6danHeH5
# 2    audio_features  1zlZxbqrIabWaH3nOJ4HdU
# 3    audio_features  3w0tCn815B8Bb4ejP2lTPJ
# 4    audio_features  5d6Mjuu2uCGRPYpFjGpCX5
# ..              ...                     ...
# 370  audio_features  7B0jvve829GGdU5kFttQTY
# 371  audio_features  3lMIgIO9HkPxnAZGmtTdpT
# 372  audio_features  5IUOU5xkzGHsRFOYNu3GSK
# 373  audio_features  5iSkdzgBBtAAkaqULGPZUd
# 374  audio_features  4Zwt0IkpzDOW2u0YfV94TK
#
#                                       uri  \
# 0    spotify:track:7oUHzZKNKUTrlU7DYxhQ7v
# 1    spotify:track:3h4T9Bg8OVSUYa6danHeH5
# 2    spotify:track:1zlZxbqrIabWaH3nOJ4HdU
# 3    spotify:track:3w0tCn815B8Bb4ejP2lTPJ
# 4    spotify:track:5d6Mjuu2uCGRPYpFjGpCX5
# ..                                    ...
# 370  spotify:track:7B0jvve829GGdU5kFttQTY
# 371  spotify:track:3lMIgIO9HkPxnAZGmtTdpT
# 372  spotify:track:5IUOU5xkzGHsRFOYNu3GSK
# 373  spotify:track:5iSkdzgBBtAAkaqULGPZUd
# 374  spotify:track:4Zwt0IkpzDOW2u0YfV94TK
#
#                                                    track_href  \
# 0    https://api.spotify.com/v1/tracks/7oUHzZKNKUTrlU7DYxhQ7v
# 1    https://api.spotify.com/v1/tracks/3h4T9Bg8OVSUYa6danHeH5
# 2    https://api.spotify.com/v1/tracks/1zlZxbqrIabWaH3nOJ4HdU
# 3    https://api.spotify.com/v1/tracks/3w0tCn815B8Bb4ejP2lTPJ
# 4    https://api.spotify.com/v1/tracks/5d6Mjuu2uCGRPYpFjGpCX5
# ..                                                        ...
# 370  https://api.spotify.com/v1/tracks/7B0jvve829GGdU5kFttQTY
# 371  https://api.spotify.com/v1/tracks/3lMIgIO9HkPxnAZGmtTdpT
# 372  https://api.spotify.com/v1/tracks/5IUOU5xkzGHsRFOYNu3GSK
# 373  https://api.spotify.com/v1/tracks/5iSkdzgBBtAAkaqULGPZUd
# 374  https://api.spotify.com/v1/tracks/4Zwt0IkpzDOW2u0YfV94TK
#
#                                                          analysis_url  \
# 0    https://api.spotify.com/v1/audio-analysis/7oUHzZKNKUTrlU7DYxhQ7v
# 1    https://api.spotify.com/v1/audio-analysis/3h4T9Bg8OVSUYa6danHeH5
# 2    https://api.spotify.com/v1/audio-analysis/1zlZxbqrIabWaH3nOJ4HdU
# 3    https://api.spotify.com/v1/audio-analysis/3w0tCn815B8Bb4ejP2lTPJ
# 4    https://api.spotify.com/v1/audio-analysis/5d6Mjuu2uCGRPYpFjGpCX5
# ..                                                                ...
# 370  https://api.spotify.com/v1/audio-analysis/7B0jvve829GGdU5kFttQTY
# 371  https://api.spotify.com/v1/audio-analysis/3lMIgIO9HkPxnAZGmtTdpT
# 372  https://api.spotify.com/v1/audio-analysis/5IUOU5xkzGHsRFOYNu3GSK
# 373  https://api.spotify.com/v1/audio-analysis/5iSkdzgBBtAAkaqULGPZUd
# 374  https://api.spotify.com/v1/audio-analysis/4Zwt0IkpzDOW2u0YfV94TK
#
#      duration_ms  time_signature
# 0         189960               4
# 1         231013               4
# 2         239920               4
# 3         238200               4
# 4         235493               4
# ..           ...             ...
# 370       228767               4
# 371       189232               4
# 372       176283               4
# 373       192155               4
# 374       251884               4
#
# [375 rows x 19 columns]

# %%
songs = songs.reset_index(drop = False)
songs
# Out:
#      index                  0            1                       2
# 0        0               Maps     Maroon 5  7oUHzZKNKUTrlU7DYxhQ7v
# 1        1            Animals     Maroon 5  3h4T9Bg8OVSUYa6danHeH5
# 2        2  It Was Always You     Maroon 5  1zlZxbqrIabWaH3nOJ4HdU
# 3        3          Unkiss Me     Maroon 5  3w0tCn815B8Bb4ejP2lTPJ
# 4        4              Sugar     Maroon 5  5d6Mjuu2uCGRPYpFjGpCX5
# ..     ...                ...          ...                     ...
# 443    443    Cross Your Mind  Niall Horan  7B0jvve829GGdU5kFttQTY
# 444    444          New Angel  Niall Horan  3lMIgIO9HkPxnAZGmtTdpT
# 445    445       No Judgement  Niall Horan  5IUOU5xkzGHsRFOYNu3GSK
# 446    446      San Francisco  Niall Horan  5iSkdzgBBtAAkaqULGPZUd
# 447    447              Still  Niall Horan  4Zwt0IkpzDOW2u0YfV94TK
#
# [448 rows x 4 columns]

# %%
final = pd.merge(songs, all_features, how= 'inner', left_on = 'index', right_on = 'index')

# %%
final = final.drop(['index'],axis =1)
final
# Out:
#                             0               1                       2  \
# 0                        Maps        Maroon 5  7oUHzZKNKUTrlU7DYxhQ7v
# 1                     Animals        Maroon 5  3h4T9Bg8OVSUYa6danHeH5
# 2           It Was Always You        Maroon 5  1zlZxbqrIabWaH3nOJ4HdU
# 3                   Unkiss Me        Maroon 5  3w0tCn815B8Bb4ejP2lTPJ
# 4                       Sugar        Maroon 5  5d6Mjuu2uCGRPYpFjGpCX5
# ..                        ...             ...                     ...
# 370         Five More Minutes  Jonas Brothers  0WxSQtLMCLcsAOhliamv5W
# 371            Take Your Time        Sam Hunt  6DEaND0SHv3sC11xobZLiy
# 372        Leave The Night On        Sam Hunt  3wx2kQWPn9p5UppQbNhPAk
# 373               House Party        Sam Hunt  1TwLKNsCnhi1HxbIi4bAW0
# 374  Break Up In A Small Town        Sam Hunt  2m7pTB0PO6HXQGpD0IuAed
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.742   0.713    1    -5.522     0       0.0303      0.020500
# 1           0.279   0.742    4    -6.460     0       0.0898      0.000185
# 2           0.613   0.765   11    -6.582     1       0.0441      0.082000
# 3           0.532   0.599    6    -6.543     1       0.0333      0.007840
# 4           0.748   0.788    1    -7.055     1       0.0334      0.059100
# ..            ...     ...  ...       ...   ...          ...           ...
# 370         0.626   0.795    1    -3.963     1       0.0451      0.015400
# 371         0.639   0.734    9    -3.953     1       0.0331      0.022800
# 372         0.723   0.726    1    -3.835     0       0.0472      0.056400
# 373         0.638   0.725   10    -6.054     1       0.0387      0.165000
# 374         0.416   0.450    3    -6.198     1       0.0269      0.123000
#
#      ...  liveness  valence    tempo            type                      id  \
# 0    ...    0.0590    0.879  120.032  audio_features  7oUHzZKNKUTrlU7DYxhQ7v
# 1    ...    0.5930    0.328  189.868  audio_features  3h4T9Bg8OVSUYa6danHeH5
# 2    ...    0.0920    0.299  103.951  audio_features  1zlZxbqrIabWaH3nOJ4HdU
# 3    ...    0.1400    0.113  130.019  audio_features  3w0tCn815B8Bb4ejP2lTPJ
# 4    ...    0.0863    0.884  120.076  audio_features  5d6Mjuu2uCGRPYpFjGpCX5
# ..   ...       ...      ...      ...             ...                     ...
# 370  ...    0.3500    0.758  123.995  audio_features  7B0jvve829GGdU5kFttQTY
# 371  ...    0.1260    0.638  108.010  audio_features  3lMIgIO9HkPxnAZGmtTdpT
# 372  ...    0.0570    0.962  100.051  audio_features  5IUOU5xkzGHsRFOYNu3GSK
# 373  ...    0.1520    0.528  136.059  audio_features  5iSkdzgBBtAAkaqULGPZUd
# 374  ...    0.1130    0.287   97.676  audio_features  4Zwt0IkpzDOW2u0YfV94TK
#
#                                       uri  \
# 0    spotify:track:7oUHzZKNKUTrlU7DYxhQ7v
# 1    spotify:track:3h4T9Bg8OVSUYa6danHeH5
# 2    spotify:track:1zlZxbqrIabWaH3nOJ4HdU
# 3    spotify:track:3w0tCn815B8Bb4ejP2lTPJ
# 4    spotify:track:5d6Mjuu2uCGRPYpFjGpCX5
# ..                                    ...
# 370  spotify:track:7B0jvve829GGdU5kFttQTY
# 371  spotify:track:3lMIgIO9HkPxnAZGmtTdpT
# 372  spotify:track:5IUOU5xkzGHsRFOYNu3GSK
# 373  spotify:track:5iSkdzgBBtAAkaqULGPZUd
# 374  spotify:track:4Zwt0IkpzDOW2u0YfV94TK
#
#                                                    track_href  \
# 0    https://api.spotify.com/v1/tracks/7oUHzZKNKUTrlU7DYxhQ7v
# 1    https://api.spotify.com/v1/tracks/3h4T9Bg8OVSUYa6danHeH5
# 2    https://api.spotify.com/v1/tracks/1zlZxbqrIabWaH3nOJ4HdU
# 3    https://api.spotify.com/v1/tracks/3w0tCn815B8Bb4ejP2lTPJ
# 4    https://api.spotify.com/v1/tracks/5d6Mjuu2uCGRPYpFjGpCX5
# ..                                                        ...
# 370  https://api.spotify.com/v1/tracks/7B0jvve829GGdU5kFttQTY
# 371  https://api.spotify.com/v1/tracks/3lMIgIO9HkPxnAZGmtTdpT
# 372  https://api.spotify.com/v1/tracks/5IUOU5xkzGHsRFOYNu3GSK
# 373  https://api.spotify.com/v1/tracks/5iSkdzgBBtAAkaqULGPZUd
# 374  https://api.spotify.com/v1/tracks/4Zwt0IkpzDOW2u0YfV94TK
#
#                                                          analysis_url  \
# 0    https://api.spotify.com/v1/audio-analysis/7oUHzZKNKUTrlU7DYxhQ7v
# 1    https://api.spotify.com/v1/audio-analysis/3h4T9Bg8OVSUYa6danHeH5
# 2    https://api.spotify.com/v1/audio-analysis/1zlZxbqrIabWaH3nOJ4HdU
# 3    https://api.spotify.com/v1/audio-analysis/3w0tCn815B8Bb4ejP2lTPJ
# 4    https://api.spotify.com/v1/audio-analysis/5d6Mjuu2uCGRPYpFjGpCX5
# ..                                                                ...
# 370  https://api.spotify.com/v1/audio-analysis/7B0jvve829GGdU5kFttQTY
# 371  https://api.spotify.com/v1/audio-analysis/3lMIgIO9HkPxnAZGmtTdpT
# 372  https://api.spotify.com/v1/audio-analysis/5IUOU5xkzGHsRFOYNu3GSK
# 373  https://api.spotify.com/v1/audio-analysis/5iSkdzgBBtAAkaqULGPZUd
# 374  https://api.spotify.com/v1/audio-analysis/4Zwt0IkpzDOW2u0YfV94TK
#
#     duration_ms  time_signature
# 0        189960               4
# 1        231013               4
# 2        239920               4
# 3        238200               4
# 4        235493               4
# ..          ...             ...
# 370      228767               4
# 371      189232               4
# 372      176283               4
# 373      192155               4
# 374      251884               4
#
# [375 rows x 21 columns]
